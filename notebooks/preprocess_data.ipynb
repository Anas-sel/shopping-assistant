# %% [markdown]
# # Notebook for preprocessing data

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
df = pd.read_csv("../raw_data/articles.csv")
df.drop(columns=["detail_desc"]).head(5)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df = pd.read_csv("../raw_data/articles.csv")
#       2 df.drop(columns=["detail_desc"]).head(5)
#
# File ~/.pyenv/versions/3.12.9/envs/shoppingassistant-env/lib/python3.12/site-packages/pandas/io/parsers/readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~/.pyenv/versions/3.12.9/envs/shoppingassistant-env/lib/python3.12/site-packages/pandas/io/parsers/readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~/.pyenv/versions/3.12.9/envs/shoppingassistant-env/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File ~/.pyenv/versions/3.12.9/envs/shoppingassistant-env/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File ~/.pyenv/versions/3.12.9/envs/shoppingassistant-env/lib/python3.12/site-packages/pandas/io/common.py:926, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     921 elif isinstance(handle, str):
#     922     # Check whether the filename is to be opened in binary mode.
#     923     # Binary mode does not support 'encoding' and 'newline'.
#     924     if ioargs.encoding and "b" not in ioargs.mode:
#     925         # Encoding
# --> 926         handle = open(
#     927             handle,
#     928             ioargs.mode,
#     929             encoding=ioargs.encoding,
#     930             errors=errors,
#     931             newline="",
#     932         )
#     933     else:
#     934         # Binary mode
#     935         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../raw_data/articles.csv'

# %%
print(df['product_group_name'].unique())
product_group = 'Shoes'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(df['product_group_name'].unique())
#       2 product_group = 'Shoes'
#
# NameError: name 'df' is not defined

# %%
print(f"The subcategories of {product_group} are: ")
df[df['product_group_name']==product_group]['product_type_name'].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(f"The subcategories of {product_group} are: ")
#       2 df[df['product_group_name']==product_group]['product_type_name'].unique()
#
# NameError: name 'product_group' is not defined

# %%
df_filtered = df[df['product_group_name']==product_group]
df_filtered.head(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df_filtered = df[df['product_group_name']==product_group]
#       2 df_filtered.head(3)
#
# NameError: name 'df' is not defined

# %%
df_filtered['index_group_name'].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df_filtered['index_group_name'].unique()
#
# NameError: name 'df_filtered' is not defined

# %%
df_trans = pd.read_csv("../raw_data/transactions_train.csv")
df_trans['t_dat']= pd.to_datetime(df_trans['t_dat'])
df_trans.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df_trans = pd.read_csv("../raw_data/transactions_train.csv")
#       2 df_trans['t_dat']= pd.to_datetime(df_trans['t_dat'])
#       3 df_trans.head()
#
# File ~/.pyenv/versions/3.12.9/envs/shoppingassistant-env/lib/python3.12/site-packages/pandas/io/parsers/readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~/.pyenv/versions/3.12.9/envs/shoppingassistant-env/lib/python3.12/site-packages/pandas/io/parsers/readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~/.pyenv/versions/3.12.9/envs/shoppingassistant-env/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File ~/.pyenv/versions/3.12.9/envs/shoppingassistant-env/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File ~/.pyenv/versions/3.12.9/envs/shoppingassistant-env/lib/python3.12/site-packages/pandas/io/common.py:926, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     921 elif isinstance(handle, str):
#     922     # Check whether the filename is to be opened in binary mode.
#     923     # Binary mode does not support 'encoding' and 'newline'.
#     924     if ioargs.encoding and "b" not in ioargs.mode:
#     925         # Encoding
# --> 926         handle = open(
#     927             handle,
#     928             ioargs.mode,
#     929             encoding=ioargs.encoding,
#     930             errors=errors,
#     931             newline="",
#     932         )
#     933     else:
#     934         # Binary mode
#     935         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../raw_data/transactions_train.csv'

# %%
df_trans_filtered = df_trans[df_trans['article_id'].isin(df_filtered['article_id'])]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df_trans_filtered = df_trans[df_trans['article_id'].isin(df_filtered['article_id'])]
#
# NameError: name 'df_trans' is not defined

# %%
df_trans_filtered.shape
# Out:
# (745521, 5)

# %%
print("Saving filtered dataFrames")
# Out:
# Saving filtered dataFrames

# %%
df_filtered.to_csv("../raw_data/articles_filtered.csv")

# %%
df_trans_filtered.to_csv("../raw_data/transactions_filtered.csv")

# %% [markdown]
# ## Filter images

# %%
import os
import shutil
from pathlib import Path

# %%
needed_article_ids = df_filtered['article_id'].unique()
needed_article_ids.shape
# Out:
# (5283,)

# %%
source_images_path = Path('../raw_data/images_256_256')
dest_images_path = Path('../raw_data/images_filtered')

# %%
copied_count = 0
missing_count = 0

for article_id in needed_article_ids:
    article_str = str(article_id).zfill(10)
    subfolder = article_str[:3]

    source_subfolder = source_images_path / subfolder
    dest_subfolder = dest_images_path / subfolder
    source_file = source_subfolder / f"{article_str}.jpg"
    dest_file = dest_subfolder / f"{article_str}.jpg"

    if source_file.exists():
        dest_subfolder.mkdir(exist_ok=True)

        shutil.copy2(source_file, dest_file)
        copied_count += 1
    else:
        missing_count += 1
        df_filtered.drop(df_filtered[df_filtered['article_id'] == article_id].index, inplace=True)
        df_trans_filtered.drop(df_trans_filtered[df_trans_filtered['article_id'] == article_id].index, inplace=True)

print(f"Copied {copied_count} images")
print(f"Missing images: {missing_count}")
print(f"Total article IDs: {needed_article_ids.shape}")
# Out:
# /tmp/ipykernel_2300/40301728.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered.drop(df_filtered[df_filtered['article_id'] == article_id].index, inplace=True)
# /tmp/ipykernel_2300/40301728.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_trans_filtered.drop(df_trans_filtered[df_trans_filtered['article_id'] == article_id].index, inplace=True)
# Copied 5156 images
# Missing images: 127
# Total article IDs: (5283,)

# %%
df_filtered.shape
# Out:
# (5156, 25)

# %%
df_trans_filtered.shape
# Out:
# (738255, 5)

# %%
df_filtered.to_csv("../raw_data/articles_filtered.csv")
df_trans_filtered.to_csv("../raw_data/transactions_filtered.csv")
